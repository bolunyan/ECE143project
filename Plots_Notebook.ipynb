# %%
import plot_functions as pf
import renewable as renew
import imageio
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
pf.Plot_Renewable_All()
# Out:
# C:\Users\swapn\Anaconda3\envs\py3.7\lib\site-packages\plotly\graph_objs\_deprecations.py:39: DeprecationWarning:
#
# plotly.graph_objs.Data is deprecated.
# Please replace it with a list or tuple of instances of the following types
#   - plotly.graph_objs.Scatter
#   - plotly.graph_objs.Bar
#   - plotly.graph_objs.Area
#   - plotly.graph_objs.Histogram
#   - etc.
# <div>
#
#
#             <div id="8aef5512-71b2-4983-a5e1-12d137c14685" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("8aef5512-71b2-4983-a5e1-12d137c14685")) {
#                     Plotly.newPlot(
#                         '8aef5512-71b2-4983-a5e1-12d137c14685',
# ...

# %%
pf.Plot_Renewable()
# Out:
# C:\Users\swapn\Anaconda3\envs\py3.7\lib\site-packages\plotly\graph_objs\_deprecations.py:39: DeprecationWarning:
#
# plotly.graph_objs.Data is deprecated.
# Please replace it with a list or tuple of instances of the following types
#   - plotly.graph_objs.Scatter
#   - plotly.graph_objs.Bar
#   - plotly.graph_objs.Area
#   - plotly.graph_objs.Histogram
#   - etc.
# <div>
#
#
#             <div id="f3509ac9-7bc4-413e-a75d-554e992343c9" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("f3509ac9-7bc4-413e-a75d-554e992343c9")) {
#                     Plotly.newPlot(
#                         'f3509ac9-7bc4-413e-a75d-554e992343c9',
# ...

# %%
source = renew.get_data_generation_1999_2019()
pf.plot_pieChart_renewable(source, '2018')

# %%
Table1 = pf.GetElectricityTrends()
pf.PlotEnergyArea(Table1)

# %%
pf.PlotEnergyBudget(Table1)

# %%
pf.PlotEnergyPop(Table1)

# %%
hydro = renew.get_data_hydro_2004_2018()
pf.plot_bar_hydro(hydro)

# %%
statehydro = renew.get_data_hydro_production()
pf.plot_bar_hydro_state(statehydro)

# %%
data = renew.get_data_hydro_potential()
pf.plot_map_hydro_potential(data)

# %%
wind = renew.scrape_wind_data_from_wiki()
# Out:
# Saved wind wiki data to Plot_Data/wind_wiki.csv

# %%
for year in range(2005, 2016):
    pf.plot_map_wind_generation(wind,str(year))

# %%
images = []
filenames = ['plots/wind_' + str(year) + '.png' for year in range(2005, 2016)]
for filename in filenames:
    images.append(imageio.imread(filename))
    images.append(imageio.imread(filename))
    images.append(imageio.imread(filename))
    images.append(imageio.imread(filename))
imageio.mimsave('plots/movie.gif', images)

# %%
from IPython.display import Image
Image(url='plots/movie.gif')
# Out:
# <img src="plots/movie.gif"/>

# %%
final = pf.GetEIAData1()
pf.PlotRenewUSA(final)

# %%
temp1 = pf.GetEIAData2()
monthwise = pf.GetEIAData3(temp1)
pf.PlotMonthwiseUSA(monthwise)

# %%
pf.PlotElectricCon(temp1)

# %%
pf.PlotSolarCon()

# %%
pf.PlotSolarGen()

# %%
pf.PlotWindProduction()
# Out:
# <div>
#
#
#             <div id="9bb61609-ccca-4f45-8834-ce3dbc9f6aac" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("9bb61609-ccca-4f45-8834-ce3dbc9f6aac")) {
#                     Plotly.newPlot(
#                         '9bb61609-ccca-4f45-8834-ce3dbc9f6aac',
# ...

# %%
pf.PlotWindPotential()
# Out:
# <div>
#
#
#             <div id="0012b9e0-7418-4fd8-b8c7-97a165e249ac" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("0012b9e0-7418-4fd8-b8c7-97a165e249ac")) {
#                     Plotly.newPlot(
#                         '0012b9e0-7418-4fd8-b8c7-97a165e249ac',
# ...

# %%
pf.PlotWindPercentPotential()
# Out:
# <div>
#
#
#             <div id="f089eda9-7102-412a-9ca2-2e761c40ab3d" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("f089eda9-7102-412a-9ca2-2e761c40ab3d")) {
#                     Plotly.newPlot(
#                         'f089eda9-7102-412a-9ca2-2e761c40ab3d',
# ...

# %%
pf.PlotSolarProd()
# Out:
# <div>
#
#
#             <div id="302bcfe3-c8b6-4bc5-9839-85658f83d2e2" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("302bcfe3-c8b6-4bc5-9839-85658f83d2e2")) {
#                     Plotly.newPlot(
#                         '302bcfe3-c8b6-4bc5-9839-85658f83d2e2',
# ...

# %%
pf.PlotSolarPotential()
# Out:
# <div>
#
#
#             <div id="9f69aba0-97d4-4775-a364-d1c44f9cef06" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("9f69aba0-97d4-4775-a364-d1c44f9cef06")) {
#                     Plotly.newPlot(
#                         '9f69aba0-97d4-4775-a364-d1c44f9cef06',
# ...

# %%
pf.PlotSolarPercentPotential()
# Out:
# <div>
#
#
#             <div id="75a14c44-097e-40ec-98f1-233572173250" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("75a14c44-097e-40ec-98f1-233572173250")) {
#                     Plotly.newPlot(
#                         '75a14c44-097e-40ec-98f1-233572173250',
# ...
